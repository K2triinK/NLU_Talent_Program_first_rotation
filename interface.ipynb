# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
#os.environ['TRANSFORMERS_CACHE'] = 'D:/.cache/'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\NicHer\\repo\\NLP'

# %%
import spacy.cli
spacy.cli.download("sv_core_news_lg")
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('sv_core_news_lg')

# %%
import gradio as gr
from most_similar_docs import *
from match_docs_with_keywords import *
from search_docs import *
from get_bedomare import *
from map_to_topics import *
from discover_topics import *
from get_keywords import *
from classifier_setfit import *
from horizon_2020_visualizer import *
from ask_docs import *
from zeroshot_classifier import *
# Out:
# C:\Users\NicHer\AppData\Local\anaconda3\envs\envname\lib\site-packages\umap\distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# C:\Users\NicHer\AppData\Local\anaconda3\envs\envname\lib\site-packages\umap\distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# ...

# %%
# !nvidia-smi
# Out:
# Thu Aug 24 08:42:19 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 511.23       Driver Version: 511.23       CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A40          TCC  | 00000000:4B:00.0 Off |                    0 |
# |  0%   29C    P8    11W / 300W |      1MiB / 46068MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
with gr.Blocks() as demo_match_keywords:
    df = gr.State([])
    gr.Markdown("Enter the keywords you want to find documents for, separated by commas. Please insert your keywords in English.\nTo make a search on the output documents of an initial search, enter new keywords and click the 'Get matching documents' button again. To make a new search, please refresh the page.")
    inp = gr.TextArea(placeholder="Insert keywords here.", label="Keywords")
    #btn_similar = gr.Button("Suggest other similar keywords")
    #kw_out = gr.Dataset(components=[gr.Textbox(visible=False)],label="Keyword suggestions")
    #btn_similar.click(fn=get_most_similar_keywords, inputs=inp, outputs=kw_out)
    inp4 = gr.TextArea(placeholder="Insert keywords you want to exclude from your document search here.", label = "Keywords to be excluded")
    inp2 = gr.CheckboxGroup(["Vinnova", "Horisont 2020"], label="Portfolio", interactive=True)
    inp3 = gr.Radio(["At least one keyword", "All of the keywords"], label="Documents that include:", interactive=True)
    btn = gr.Button("Get matching documents")
    out1 = gr.Textbox(label='Count')
    out2 = gr.File(label="Download the file here")
    out3 = gr.Dataframe(wrap=True)
    btn.click(fn=return_matching_documents, inputs=[inp, inp2, inp3, inp4, df], outputs=[out1, out2, out3, df])

# %%
with gr.Blocks() as demo_similar:
    gr.Markdown("<h1>Find similar projects</h1>")
    inp = gr.TextArea(placeholder="Insert project text here.", label="Project text")
    inp2 = gr.CheckboxGroup(["Vinnova", "Horisont 2020"], label="Portfolio", interactive=True)
    btn = gr.Button("Get most similar projects")
    out1 = gr.File(label="Download the file here.")
    out2 = gr.Dataframe(wrap=True)
    btn.click(fn=get_most_similar_documents, inputs=[inp, inp2], outputs=[out2, out1])

# %%
with gr.Blocks() as search:
    gr.Markdown("<h1>Search in documents</h1>")
    inp = gr.Textbox(placeholder="", label="Search query")
    inp2 = gr.CheckboxGroup(["Vinnova", "Horisont 2020"], label="Portfolio", interactive=True)
    inp3 = gr.Slider(minimum=1, maximum=500, step=1, value=20, label="Select the number of documents to return")
    btn = gr.Button("Search")
    out2 = gr.File(label="Download the file here.")
    out1 = gr.Dataframe(wrap=True)
    btn.click(fn=get_search_results, inputs=[inp, inp2, inp3], outputs=[out1, out2])

# %%
with gr.Blocks() as bedomare:
    gr.Markdown("<h1>Find bedömare</h1>")
    inp = gr.TextArea(placeholder="", label="Project text")
    inp2 = gr.Slider(minimum=1, maximum=50, step=1, value=10, label="Select the number of bedömare to return.")
    btn = gr.Button("Find bedömare")
    out1 = gr.File(label="Download the file here.")
    out2 = gr.Dataframe(wrap=True)
    btn.click(fn=get_bedomare, inputs=[inp, inp2], outputs=[out2, out1])

# %%
with gr.Blocks() as maps:
    gr.Markdown("<h1>Map texts to existing topics</h1>")
    inp = gr.DataFrame(label="Topics to map to", interactive=True, headers=['Topic title', 'Example text or topic summary'])
    inp2 = gr.File(label="Upload your file.")
    inp3 = gr.Radio(value = 'EN', choices=['EN', 'SV'], interactive=True, label='Choose language')
    btn = gr.Button("Map to Topics")
    out1 = gr.Plot(label="Topics map")

    btn.click(fn=map_to_topics, inputs = [inp, inp2, inp3], outputs = out1)

# %%
with gr.Blocks() as discover:
    gr.Markdown("<h1>Discover topics</h1>")
    inp1 = gr.File(label="Upload your file")
    inp2 = gr.Radio(value = 'EN', choices=['EN', 'SV'], interactive=True, label='Choose language')
    inp3 = gr.Slider(mininum=4, maximum=20, value=6, step=1, label = 'Number of Topics', interactive=True)
    inp4 = gr.Radio(value = 'Disallow outliers', choices=['Disallow outliers', 'Allow outliers'], interactive=True, label='Choose whether all documents need to be part of a topic group')
    btn = gr.Button("Discover Topics")
    out_coherence = gr.Slider(mininum=0, maximum=100, value = 0, label = 'Topic Model Coherence Score', interactive=False)
    out_diversity = gr.Slider(mininum=0, maximum=100, value=0, label = 'Topic Model Diversity Score', interactive=False)
    out1 = gr.Plot(label="Topics map")
    out_excel = gr.File(label="Download file here")
    out_df = gr.Dataframe(wrap=True)
    
    btn.click(fn=discover_topics, inputs = [inp1, inp2, inp3, inp4], outputs = [out1, out_coherence, out_diversity, out_df, out_excel])

# %%
with gr.Blocks() as demo_keywords:
    gr.Markdown("<h1>Extract keywords</h1>")
    inp = gr.TextArea(placeholder="Insert project text here", label="Project text")
    btn = gr.Button("Extract keywords")
    out = gr.TextArea(label="Extracted keywords")
    btn.click(fn=get_keywords, inputs=inp, outputs=out)

# %%
with gr.Blocks() as classifier:
    gr.Markdown("<h1>Train a classifier & label documents</h1>")
    state = gr.State([])
    inp1 = gr.File(label="Upload an Excel file with the columns 'project_id', 'text' and 'label'. Please make sure to fill in the label column for at least 10 examples per class. Leave the rest of the label column empty. If you want to decide yourself which documents should be in the test set, add a column called 'split' where the possible values are 'train' and 'test'.")
    inp2 = gr.Radio(value = 'EN', choices=['EN', 'SV'], interactive=True, label='Choose language')
    inp4 = gr.Radio(value = 'Only use the provided examples', choices=['Only use the provided examples', 'Add synthetic examples'], interactive=True, label='Choose whether to generate synthetic data to increase the number of examples')
    btn = gr.Button("Train & Evaluate initial classifier")
    current_test_acc = gr.Slider(mininum=0, maximum=100, value = 0, label = 'Current validation accuracy', interactive=False)
    out1 = gr.DataFrame(label="Example predictions", interactive=True, headers=['project_id', 'text', 'label'], wrap=True)
    btn.click(train_initial_model, inputs=[inp1,inp2,inp4,state], outputs=[current_test_acc, out1, state])
    with gr.Row():
        btn_finish = gr.Button("I am happy with the model, train final model and classify all documents!")
        btn_continue = gr.Button("I am not happy with the model and have corrected the predicted labels above, continue training!")
    final_test_acc = gr.Slider(mininum=0, maximum=100, value = 0, label = 'Final validation accuracy', interactive=False)
    out_file = gr.File(label="Download the file here")
    out2 = gr.DataFrame(label="Final predictions", interactive=False, headers=['project_id', 'text', 'label'], wrap=True)
    btn_continue.click(continue_training_model, inputs=[out1, state], outputs=[current_test_acc, out1, state])
    btn_finish.click(train_final_model, inputs=[state], outputs=[final_test_acc, out2, out_file, state])

# %%
with gr.Blocks() as visualize_horizon_2020:
    gr.Markdown("<h1>Visualize Horizon 2020 projects and actors simply by asking questions!</h1>")
    inp1 = gr.File(label="Upload an Excel file with a 'project_id' column.")
    inp2 = gr.Radio(value = 'visualize projects', choices=['visualize projects', 'visualize actors'], interactive=True, label='I want to')
    inp3 = gr.Textbox(label="Question field", placeholder="Write your question here!")
    btn = gr.Button("Generate answer!")
    out_text = gr.TextArea(label="AI generated code")
    out_plot = gr.Plot(label="Generated chart")
    btn.click(get_plot, inputs=[inp1,inp2, inp3], outputs=[out_text, out_plot])

# %%
with gr.Blocks() as ask_internal_docs:
    gr.Markdown("<h1>Ask PDFs!</h1>")
    inp3 = gr.Textbox(label="Question field", placeholder="Write your question here!")
    btn = gr.Button("Generate answer!")
    out_text = gr.TextArea(label="AI generated answer")
    btn.click(ask_docs, inputs=inp3, outputs=out_text)

# %%
with gr.Blocks() as zeroshot_cls:
    gr.Markdown("<h1>Classify without examples!</h1>")
    inp_text = gr.TextArea(label="Project text", placeholder="Paste the text you want to classify here!")
    inp_cat = gr.Textbox(label="Categories", placeholder="food, integration, other (Replace with your own labels!)")
    btn = gr.Button("Classify!")
    out_text = gr.Textbox(label="AI generated classification")
    btn.click(classify_0shot, inputs=[inp_text, inp_cat], outputs=out_text)

# %%
demo = gr.TabbedInterface([demo_match_keywords, search, demo_similar, classifier, discover, maps, bedomare, demo_keywords, visualize_horizon_2020, ask_internal_docs, zeroshot_cls], 
                          ["Find documents by keywords", "Find relevant documents", "Find most similar documents", "Classify documents", "Discover Topics",
                           "Map to Topics", "Rank bedömare", "Extract keywords", "Visualize Horizon 2020", "Ask PDFs!", "Zero-shot classification"])

if __name__ == "__main__":
    demo.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# ...

# %%
nlp = spacy.load("en_core_web_lg")

# %%
nlp_docs = "hello my name is niclas and i like vegetables".split()

nlp_tags_list = []
index = 0
for i, doc in enumerate(nlp.pipe(nlp_docs)):
    for token in doc:
        temp = []
        temp.append(token.text)
        temp.append(token.lemma_)
        temp.append(token.pos_)
        temp.append(i)
        nlp_tags_list.append(temp)
    index += 1

# %%
nlp_tags_list
# Out:
# [['hello', 'hello', 'INTJ', 0],
#  ['my', 'my', 'PRON', 1],
#  ['name', 'name', 'VERB', 2],
#  ['is', 'be', 'AUX', 3],
#  ['niclas', 'nicla', 'NOUN', 4],
#  ['and', 'and', 'CCONJ', 5],
#  ['i', 'I', 'PRON', 6],
#  ['like', 'like', 'INTJ', 7],
#  ['vegetables', 'vegetable', 'NOUN', 8]]

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
#model_name = "AI-Sweden-Models/gpt-sw3-6.7b-v2-instruct"
AUTH_TOKEN = "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"
model_name = "AI-Sweden-Models/gpt-sw3-6.7b-v2"

model = AutoModelForCausalLM.from_pretrained(model_name, device_map='auto', use_auth_token=AUTH_TOKEN)
# Out:
# ...
# ...
# ...
# Loading checkpoint shards: 100%|█████████████████████████████████████████████████████████| 3/3 [00:15<00:00,  5.04s/it]

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name, use_auth_token=AUTH_TOKEN)
